# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python split_sentences.py
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# python3: can't open file '/content/split_sentences.py': [Errno 2] No such file or directory

# %%
import os
import sys
import spacy

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c2ac116164fd> in <cell line: 1>()
# ----> 1 os.pwd
#
# AttributeError: module 'os' has no attribute 'pwd'

# %%
# !git clone https://github.com/abecode/teaching_reviews.git
# Out:
# Cloning into 'teaching_reviews'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 34 (delta 0), reused 34 (delta 0), pack-reused 0
# Receiving objects: 100% (34/34), 32.70 KiB | 2.51 MiB/s, done.

# %%
nlp = spacy.load("en_core_web_sm")

directory = "teaching_reviews/data"

# if len(sys.argv) > 1:
#     directory = sys.argv[1]

# %%
sentencizer = nlp.add_pipe("sentencizer")

# %%
for fname in os.listdir(directory):
  # print(fname)
    with open(os.path.join(directory, fname)) as f:
        for line in f:
            #print(line.strip())
            doc = nlp(line)
            for sent in doc.sents:
                print(fname, sep="\t")
                print(sent)
# Out:
# 202220SEIS631-02.txt
# Prof Abe is excellent in articulating concepts and very patient with students.
# 202220SEIS631-02.txt
# I learned quite a lot useful knowledge that I can apply to my work and research.
#
# 202220SEIS631-02.txt
# The course is trying to do too much in short time and there isn't enough time to full learn the subject before having to move on to next.
# 202220SEIS631-02.txt
# No regular practice to make sure I grasp the concept until a test when I realize I didn't actually understand it.
#
# 202220SEIS631-02.txt
# Great course.
# 202220SEIS631-02.txt
# Learnt new things that making more competitive for data analysis.
# 202220SEIS631-02.txt
# Sometime reading the book is hard and correlate with R seems little challenging.
# 202220SEIS631-02.txt
# Definitely enjoying R Studio, RMarkdown and Github.
#
# 202220SEIS631-02.txt
# Very patient and an overall a good prof.
#
# 202220SEIS631-02.txt
# I think Abe could come more prepared to class to show examples from the book.
# 202220SEIS631-02.txt
# Often it felt like he was walking through them for the first time while showing us.
# 202220SEIS631-02.txt
# He understands the concepts, but at times it got lost while sorting through the problem.
# 202220SEIS631-02.txt
# Also it felt broken between learning the statistical equations in the textbook versus R. I really enjoyed working in R and doing the problems in the textbook, I just wish there was more of a tie, it would help solidify concepts and theories and equations.
# 202220SEIS631-02.txt
# It would be able to show R's capabilities and also be able to feel comfortable using it in everyday work situations.
# 202220SEIS631-02.txt
# Right now I feel there's so much in R that we've gone over in class
# 202220SEIS631-02.txt
# but I don't know where or how to use it/explain it and then so much more that we never went over that could be relevant.
#
# 202220SEIS631-02.txt
# I really enjoyed the homework format provided and learned a lot through them.
# 202220SEIS631-02.txt
# Would love to have more homework that practically applies the readings in RStudio and have more questions to solve that would be similar to the assigned quizzes.
#
# 202220SEIS631-02.txt
# I enjoyed the course quite a bit.
# 202220SEIS631-02.txt
# I don’t have a stats background, but concepts and methods were understandable after having spent time with it.
# 202220SEIS631-02.txt
# Professor is very understanding of the range in class stats knowledge and was fair in their creation and assessment of assignments, quizzes and exams.
# 202220SEIS631-02.txt
# I liked that the final project gave us total creativity to explore a topic of our choice.
# 202220SEIS631-02.txt
# I do think we could have used a bit more classroom breakouts to discuss the reading with fellow classmates.
# 202220SEIS631-02.txt
# Since there were no group projects, it was a little harder trying to get to know my classmates.
# 202220SEIS631-02.txt
# Surprisingly, more people turned their cameras on during breakouts than in the larger group.
# 202220SEIS631-02.txt
# A few more smaller group settings could help for future courses.
# 202220SEIS631-02.txt
# Overall, a really great course and kept my interest in statistics and R.
#
# 202220SEIS630-01.txt
# Knowledgeable about the subject and makes class interesting.
#
# 202220SEIS630-01.txt
# I would like to say thanks to the professor that he has given us good knowledge about this course.
# 202220SEIS630-01.txt
# Thank you so much, professor.
#
# 202220SEIS630-01.txt
# There probably should have been more assignments or quizzes.
# 202220SEIS630-01.txt
# Having one bad day/week can cost a lot.
#
# 202220SEIS630-01.txt
# Better preparation for more fluid classes.
# 202220SEIS630-01.txt
# Less time spent on tangents, more on the material.
# 202220SEIS630-01.txt
# Time wasted at the beginning of class is mostly unnecessary.
#
# 202220SEIS630-01.txt
# Professor is excellent.
# 202220SEIS630-01.txt
# I would recommend the class with Abe anytime.
#
# 202220SEIS630-01.txt
# I enjoyed this course, although there were many times that the professor spent too long trying to answer one student's individual question instead of requesting them to attend office hours.
# 202220SEIS630-01.txt
# This meant that we frequently didn't finish lectures or get to dive into the hands on activity.
#
# 202220SEIS630-01.txt
# N/A
#
# 202220SEIS630-01.txt
# Prof. Abe is an excellent teacher.
# 202220SEIS630-01.txt
# He is very kind and approachable person with great subject knowledge.
# 202220SEIS630-01.txt
# He is gem of a person.
# 202220SEIS630-01.txt
# Thank for teaching us!
#
# 202220SEIS630-01.txt
# Professor Kazemzadeh is definitely knowledgeable in this subject, however he might make a better professor for undergraduate versus graduate level students.
# 202220SEIS630-01.txt
# While he's very nice and patient and takes the time to listen to students, often he will get distracted and go on a tangent about something that is deeper than where we are in the class/level of understanding for most students.
# 202220SEIS630-01.txt
# This then creates a ripple effect where class goes past 9pm which can be frustrating since most of us work full time jobs prior to class, it's important to respect our time as well and end class as scheduled.
# 202220SEIS630-01.txt
# he in class hands-on activities also seem unstructured and in the end don't prepare us for the homework/final project.
# 202220SEIS630-01.txt
# I think the class needs a better balance of lecture versus hands-on activities rather than just rushing through it at the end of class.
# 202220SEIS630-01.txt
# We spent more time doing work in OracleDataModeler in one class than it felt like we did of database creation/querying, even though Professor kept saying it's more important to be comfortable and capable querying than building models, I felt we could have gotten deeper on writing complex queries which would be more beneficial.
#
# 202220SEIS630-01.txt
# The Professor has very good hands-on knowledge of the database.
# 202220SEIS630-01.txt
# His practical examples helped us understand the concepts.
#
# 201940SEIS631-01.txt
# I enjoyed a lot of the content, as well as getting experience using R Studio, of which I wish there were perhaps not more assignments but more challenging assignments.
# 201940SEIS631-01.txt
# You come across as very nice and lenient grading, and your teaching style was good at the start of the class, but as the material got more difficult it seemed you faltered more during the lectures going over the slides.
# 201940SEIS631-01.txt
# If you struggle with explaining this content to us, then we will also struggle.
# 201940SEIS631-01.txt
# I feel like my knowledge of the most difficult content is shaky.
# 201940SEIS631-01.txt
# Following along with your thought process as you solve a problem, only to have you get the wrong answer and backpedal, made it hard to develop the correct way to approach a problem, ie requiring knowledge of the answer beforehand.
# 201940SEIS631-01.txt
# I suggest getting more familiar with these slides, or if they are not your own slides, making your own set as a fresh start.
#
# 201940SEIS631-01.txt
# I give this professor a lot of credit for choosing a solid text, responding quickly to questions via a variety of forms of communication, and for soliciting and acting on feedback to improve his class.
# 201940SEIS631-01.txt
# He's approachable, knowledgeable and I believe he cares about the success of his students.
# 201940SEIS631-01.txt
# Unfortunately, like so many classes in the grad software program, this class is characterized by: 1.
# 201940SEIS631-01.txt
# An assignment to read a chapter 2.
# 201940SEIS631-01.txt
# A class session spent going over PowerPoint slides that reiterate what was in the chapter but without bringing focus or clarity to the material 3.
# 201940SEIS631-01.txt
# A smallish assignment that checks the box for "hands on work" 4.
# 201940SEIS631-01.txt
# Two massive tests that comprise 60-80% of the grade (60% in this particular class) I believe this class, like so many others in the grad software program, would benefit from being flipped.
# 201940SEIS631-01.txt
# Lectures should be viewed in video form outside of class while class time should be spent doing hands on work or exercise problems with the professor present to guide and assist.
# 201940SEIS631-01.txt
# This hands on work should highlight the most important material from the book and ideally would reiterate concepts from previous class sessions.
# 201940SEIS631-01.txt
# I believe the "bunch of lectures and two big tests" system that so many professors in this program seem to implement simply isn't conducive to learning.
# 201940SEIS631-01.txt
# People tend to learn best with lots of opportunities for success and failure that present important concepts to them again and again in a variety of situations.
# 201940SEIS631-01.txt
# Having two large tests that comprise so much of a grade simply incentivizes students to cram and forget, instead of pushing them to exercise and internalize.
# 201940SEIS631-01.txt
# I'd also acknowledge that the "bunch of lectures and two big tests" system is certainly easier on professors who may be carrying a large course load.
# 201940SEIS631-01.txt
# Crafting a flipped course, or one with more focused and exercise-based material, is no small task.
# 201940SEIS631-01.txt
# But the frequency of this model in the St. Thomas grad software program is disheartening - especially at $3,400 per class.
# 201940SEIS631-01.txt
# So while I don't fault Prof. Kazamzadeh for being another in a long line of professors who run a class in the "read, lecture, pass two massive tests" style, it's frustrating that I'm writing a review like this once again.
#
# 201940SEIS631-01.txt
# I am struggling in this class.
# 201940SEIS631-01.txt
# I need more examples than what is presented in class.
# 201940SEIS631-01.txt
# Also I need re-enforcement of “why” we might choose a statistical technique and “what” it means.
# 201940SEIS631-01.txt
# We spent lots of time on “how”.
# 201940SEIS631-01.txt
# I’m relying a lot on Khan academy to supplement what I’m missing in class.
# 201940SEIS631-01.txt
# I do tend to learn slower than my peers
# 201940SEIS631-01.txt
# so maybe it’s me.
# 201940SEIS631-01.txt
# Have you ever considered a separate lab?
# 201940SEIS631-01.txt
# There is never enough time for the R portion of the class.
#
# 202220SEIS630-02.txt
# I really enjoyed learning from Abe this semester.
# 202220SEIS630-02.txt
# It is very, very clear that he has a wealth of knowledge both on the direct subject matter of databases but also just software engineering as a whole.
# 202220SEIS630-02.txt
# Abe is always willing to spend extra time answering questions for students and going over difficult topics.
# 202220SEIS630-02.txt
# I think the only issue I would have with Abe is that occasionally class ends up going long, and normally only by 5-10 minutes but when class is already 3 hours long and ending at 9 PM, it would be highly preferred to always end on time.
# 202220SEIS630-02.txt
# The times it has been the most frustrating is when going over the homework that is due the next week and spending excess time talking though it instead of letting the student(s) do the homework on their own.
# 202220SEIS630-02.txt
# Overall, I think Abe is a great professor and I really enjoyed him.
#
# 202220SEIS630-02.txt
# Thanks for presenting us this class throughout the semester, prof.
# 202220SEIS630-02.txt
# Abe!
#
# 202220SEIS630-02.txt
# Excellent teaching, Professor was always helpful, always made the class interactive though class was online.
#
# 202220SEIS630-02.txt
# I think the administrative and curricular aspects of the course are very well organized and present clear expectations.
# 202220SEIS630-02.txt
# I also think the professor wants to teach an effective course and it shows.
# 202220SEIS630-02.txt
# However I think the traditional lecture format is not a great pairing with his delivery style and the course could be made more effective by creating a more hands on coding environment for the students during the time.
#
# 202220SEIS630-02.txt
# I would have preferred to take this course in an in person setting.
# 202220SEIS630-02.txt
# I felt the virtual format made it more difficult for me to engage with the course material.
#
# 201940SEIS632-01.txt
# I think having the hands-on activities at beginning of class helps ensure that we have enough time to get through the handouts, and also keeps attention better.
# 201940SEIS632-01.txt
# I found the hands-on activities useful, especially Tableau.
#
# 201940SEIS632-01.txt
# The lectures were too long.
# 201940SEIS632-01.txt
# This is the first graduate level class I have taken at UST where the professor lectured the entire class for almost every class.
# 201940SEIS632-01.txt
# That being said, Abe did a great job in his lectures using real-life examples and an easy-to-follow format.
# 201940SEIS632-01.txt
# Consistent due dates each week on homework and quizzes would be very helpful in this class.
# 201940SEIS632-01.txt
# Enterprise Minor is a difficult software to use and I commend Abe's efforts on teaching us in this software.
# 201940SEIS632-01.txt
# It would be great if UST could find a software that is more widely-used and easier to use for this class (I would have been willing to pay money to use better software).
#
# 201940SEIS632-01.txt
# This course is highly disorganized, and the structure of the final project seems nearly useless for evaluating student learning, as it depends too significantly on the process of finding and organizing a meaningful data set rather than the analytics and visualization of the title.
# 201940SEIS632-01.txt
# I don't feel this class meaningfully prepared me to use the technology, or to understand the concepts, as too much time was spent acquiring usable data.
#
# 202140SEIS630-03.txt
# Prof. Abe is an excellent instructor.
# 202140SEIS630-03.txt
# The class content can be more engaging with in-class coding sessions along with slides.
#
# 202140SEIS630-03.txt
# good
#
# 202140SEIS630-03.txt
# truly appreaviate professor for well organized and arragement for every class.\great professor.
#
# 202140SEIS630-03.txt
# Really enjoyed your teaching style.. the atmosphere you have created on the class really encouraged me to ask questions and explore more.
# 202140SEIS630-03.txt
# This is coming from a person who is introvert (INFJ).
# 202140SEIS630-03.txt
# Last but not least, I have loved the jazz music you played in between the active sessions.
# 202140SEIS630-03.txt
# Thank you, Abe!
#
# 202140SEIS630-03.txt
# Overall a good class experience and I enjoyed attending every class session.
# 202140SEIS630-03.txt
# I would definitely find other courses with the same professor.
# 202140SEIS630-03.txt
# One recommendation I would give is to have some type of fun online quiz game (ex: Quizizz.com) at the beginning of class rather than breakout discussion rooms.
# 202140SEIS630-03.txt
# This would help students get a good recap of the terms or vocab of what was taught in the previous class session.
#
# 202140SEIS630-03.txt
# It is obvious that Abe wants to teach the information in the class and that he wants us to succeed.
# 202140SEIS630-03.txt
# I also appreciate his honesty when not as sure on topics and is open to feedback from the class.
# 202140SEIS630-03.txt
# I understand sql is not a language that Abe is as comfortable with, but is always open for questions and willing to research on the spot.
# 202140SEIS630-03.txt
# I feel that the survey assignment was a create way to incorporate our data into creating tables and modifying tables.
# 202140SEIS630-03.txt
# I liked the concepts of the other assignments moving closer to the final project.
# 202140SEIS630-03.txt
# I appreciate the "chose your own adventure" final project approach.
# 202140SEIS630-03.txt
# I feel that this does give students more of an option to explore areas they are interested in.
# 202140SEIS630-03.txt
# There are a few areas in the class that I don't feel was as successful.
# 202140SEIS630-03.txt
# I am sure this is also different because online (which I took this section because it was offered online), but most of the members of my assigned breakout groups did not actually talk, work collaboratively, or even engage past the first group assignment.
# 202140SEIS630-03.txt
# I understand the goal of what the breakout groups was aiming for, but I don't think it was a productive use of time all of the time.
# 202140SEIS630-03.txt
# It may be nice to have a few more breaks.
# 202140SEIS630-03.txt
# Abe again is very eager to teach and share information with the class, but sometimes I think our brains need a few more short breaks.
# 202140SEIS630-03.txt
# Again, I enjoy being able to take my break at home because class is online, but could still use a few more bio / brain breaks.
# 202140SEIS630-03.txt
# I liked the hands on examples that were worked on in class, but maybe more of those examples could be integrated more in when going through the lecture part in the slides and looking at the book.
# 202140SEIS630-03.txt
# Sometimes it is helpful to break up the text a bit more too for tired brains.
# 202140SEIS630-03.txt
# Overall, the ratings I scored in this survey will seem low, but a large part of it is due to my level of comfort and experience with databases prior to class.
# 202140SEIS630-03.txt
# Thank you Abe for teaching this class and teaching it online!
#
# 202140SEIS630-03.txt
# The professor might not have field experience in this class.
# 202140SEIS630-03.txt
# We rely more on the textbook and do not gain additional information further from that.
# 202140SEIS630-03.txt
# Professor stumbles throughout the lesson and seems to be stumped by more in depth questions in class.
# 202140SEIS630-03.txt
# I have gained more knowledge from going to youtube to understand how to do the assignments from my professor.
# 202140SEIS630-03.txt
# The quizzes are more of a seek and find terminology from the text book than truly understanding the material.
# 202140SEIS630-03.txt
# I was disappointed by this course.
# 202140SEIS630-03.txt
# This might be better suited for an intro in the undergraduate level than for a master's course.
#
# 202140SEIS630-03.txt
# I like the right speed in which Prof. Abe taught and the flexibility he provides where we can do a make up session with other day in the week.
# 202140SEIS630-03.txt
# Had a very good experience and learned new theoretical and practical knowledge.
# 202140SEIS630-03.txt
# Thank you Professor
#
# 202140SEIS630-03.txt
# I would appreciate more hands-on activity in class than lectures.
# 202140SEIS630-03.txt
# I think having example of codes and walking through what it does and creating it would help with the learning process more.
#
# 202040SEIS631-03.txt
# I feel so lucky to be one of members in Abe's class.
# 202040SEIS631-03.txt
# Abe is a excellent professor who taught us in a interesting way with abundant knowledge.
#
# 202040SEIS631-03.txt
# Far too often allowed the class to be taken aside by students to answer their specific technological questions, especially in the middle of lectures.
# 202040SEIS631-03.txt
# These inopportune interruptions greatly diminished my learning experience, as I imagine it did for others as well.
# 202040SEIS631-03.txt
# It does not help that there was no ability for Prof. Kazemzadeh's to give literal hands-on help to those students.
# 202040SEIS631-03.txt
# This course does not work very well as an online synchronous class, perhaps online asynchronous would be better.
# 202040SEIS631-03.txt
# I have no doubt in Prof. Kazemzadeh's expertise in the field, and given a normal semester, I believe I would have much better feedback to give.
#
# 202040SEIS631-03.txt
# Abe is a wonderful human.
# 202040SEIS631-03.txt
# He is the kind of person I would like to be friends with.
# 202040SEIS631-03.txt
# However, he is hard to learn from.
# 202040SEIS631-03.txt
# It feels as though he is either learning along with us or understands the material so well he struggles to break down the concepts.
# 202040SEIS631-03.txt
# I do like him as a person though.
#
# 202040SEIS631-03.txt
# Generally, this course is well designed for students who need to practice more in data analyses.
# 202040SEIS631-03.txt
# The professor has extensive knowledge to lead the course and provides good examples.
#
# 202040SEIS631-03.txt
# We have covered all topics from one book and solved the problems in it.
# 202040SEIS631-03.txt
# The book has covered most of the topics nicely and we got all doubts cleared by professor.
# 202040SEIS631-03.txt
# Thanks you !
#
# 202040SEIS631-03.txt
# I really liked this class.
# 202040SEIS631-03.txt
# I liked the layout and learning from the different students.
# 202040SEIS631-03.txt
# The breakout discussion groups helped me get to know my peers and that was useful for another class as we could have a study group.
# 202040SEIS631-03.txt
# Overall, great job!
#
# 202040SEIS631-03.txt
# I really enjoyed this course!
# 202040SEIS631-03.txt
# I thought your assignments were an excellent way to learn the material.
#
# 202040SEIS631-03.txt
# I appreciated the amount of time and effort he went to teach us R and make us comfortable with it.
# 202040SEIS631-03.txt
# I also appreciated his flexibility with the assignments and exams so that we learn the concepts more.
#
# 202040SEIS631-03.txt
# Professor is very passionate about teaching this course.
# 202040SEIS631-03.txt
# He is very engaging and inspires me to work hard to learn as much as possible by internalizing the acquired knowledge.
#
# 202020SEIS631-02.txt
# I really liked his teaching approach.
# 202020SEIS631-02.txt
# He takes attention to what his students suggest and also checks if the students understood what he taught.
# 202020SEIS631-02.txt
# He is also a nice human being.
#
# 202020SEIS631-02.txt
# Prof Abe is great.
# 202020SEIS631-02.txt
# He taught us many statistics knowledge, used many latest dataset during our class, adapted flip teaching method.
# 202020SEIS631-02.txt
# He is very nice, and professional for any questions from student.
# 202020SEIS631-02.txt
# Thanks Abe
#
# 202020SEIS631-02.txt
# Adapted very well to the challenges of transitioning to online learning, encouraged participation and was always open and responsive to questions.
# 202020SEIS631-02.txt
# Sought out his section for a future registered class because his style works well for me and I appreciate his dedication.
# 202020SEIS631-02.txt
# Great first class and professor to have for my program.
#
# 202020SEIS631-02.txt
# This course was difficult to follow along with as the tests and lectures didn't seem to correspond with the homework.
# 202020SEIS631-02.txt
# Alot of the work we did that was graded was not what we were tested on which led to a lot of confusion and many adjustments after the tests were graded.
# 202020SEIS631-02.txt
# I felt the communication was a little lacking as much as of it wasn't available on canvas and was done through the lectures which made it hard to reference back to.
# 202020SEIS631-02.txt
# I think our professor was knowledgable and super nice but that the class as a whole had to drive most of the discussion and routinely ask for clarification on each assignment and each topic.
#
# 202020SEIS631-02.txt
# Abe is very friendly, understanding and knowledgeable!
# 202020SEIS631-02.txt
# I enjoyed this class alot even during COVID-19!
#
# 202120SEIS630-01.txt
# Maybe find a textbook that only includes the language that is taught -- sometimes it was confusing when the information did not apply to oracle SQL.
# 202120SEIS630-01.txt
# Maybe work more in livesql from the beginning.
# 202120SEIS630-01.txt
# Just to get more comfortable actually programming.
#
# 202120SEIS630-01.txt
# Thanks for keeping this course fresh and relevant, Abe
#
# 202120SEIS630-01.txt
# apply book chapter skills to the class project on a weekly basis like the quizes quizd us on the book knowleage.
# 202120SEIS630-01.txt
# it would be more helpful to abosrb and retain the learning matrials.
#
# 202120SEIS630-01.txt
# I would have liked to have more hands on coding and building during class rather than reviewing the reading as much as we had.
#
# 202120SEIS630-01.txt
# Awesome course, awesome professor!
#
# 202120SEIS630-01.txt
# Abe is wonderful and I would take a course from him again.
# 202120SEIS630-01.txt
# He understands that we are all busy people, coming in with different backgrounds, and clearly worked hard to make sure we all learned something.
# 202120SEIS630-01.txt
# He was transparent that it was his first time teaching this course, and I could imagine a few changes to improve it.
# 202120SEIS630-01.txt
# I would have preferred that our weekly break out sessions were with a consistent group of people, so that we could have the opportunity to get to know our classmates better.
# 202120SEIS630-01.txt
# Depending on the combination of students, sometimes the break out room conversations were interesting, but I think that small group time would have been better served doing hands-on exercises together instead of discussing the textbook.
# 202120SEIS630-01.txt
# Actually, overall I wish there was much more hands-on work and less textbook review.
# 202120SEIS630-01.txt
# In our careers we need to have the skills more than we need to know the vocabulary.
# 202120SEIS630-01.txt
# If I didn't already know SQL I'm not sure I would have come away from this course being able to execute a medium complexity query, which I think should be a goal outcome.
# 202120SEIS630-01.txt
# I thought the final project was great, and the open-ended description allowed us all to choose our own adventure based on our interests and background knowledge.
# 202120SEIS630-01.txt
# I think we could have started the final project even earlier in the term and ideally had a round of feedback from Abe during the process.
# 202120SEIS630-01.txt
# The decision to have us prerecord the project presentations was truly brilliant.
# 202120SEIS630-01.txt
# Saved lots of presentation anxiety, potential for technical difficulties, and ensured (hopefully) that everyone comes in under 5 min! Abe utilized the virtual learning tools very well, I appreciated the organized Canvas course, the class announcements, and the discussions.
# 202120SEIS630-01.txt
# I thought it worked well to share with OneDrive even if students had a strangely hard time remembering to make the links actually be links!
# 202120SEIS630-01.txt
# Next term, I'd suggest adding a short break or two during classes, letting us get to know our small groups, and reducing the percentage of lectures and increasing the amount of hands on exercises (all of these things would also encourage cameras on, since it would be less passive).
# 202120SEIS630-01.txt
# Thanks for the course, Abe!
#
# 202120SEIS630-01.txt
# Abe is a great professor, clearly very knowledgeable about database management systems and design.
# 202120SEIS630-01.txt
# He is able to explain complex topics in understandable terms and is always available to answer questions or provide feedback on assignments.
# 202120SEIS630-01.txt
# One thing that I would have liked better about the course structure would be if we had started to design our model at the beginning of the semester and slowly add to it as we learned new topics week by week, rather than learning about all of the topics and then applying them in the last month of class.
# 202120SEIS630-01.txt
# I also think that having randomized groups each week was good for meeting the majority of the classmates, however it may have been more beneficial to work with the same people each week and become more familiar with each other's project topics.
# 202120SEIS630-01.txt
# Overall I really enjoyed this course and it provided a solid foundation for me to learn more in the field of database management systems.
# 202120SEIS630-01.txt
# I would recommend Abe as a professor to anyone looking to take this course.
#
# 202120SEIS630-01.txt
# Recommend having more practice SQL exercises for the class.
#
# 202320SEIS630-03.txt
# I like Abe a lot but sometimes the class feels very unorganized.
# 202320SEIS630-03.txt
# Also, sometimes he doesn't have great time management and will spend way too much class time helping 1 or 2 people troubleshoot their problems.
# 202320SEIS630-03.txt
# In the future he should really just tell people to talk to him after class instead of spending 30-60 minutes during class on it.
# 202320SEIS630-03.txt
# He is a fair grader and very helpful
# 202320SEIS630-03.txt
# so I would definitely take another class from him again.
#
# 202320SEIS630-03.txt
# Awesome professor, appreciated the flexibility and availability.
#
# 202320SEIS630-03.txt
# the class is very slow.
# 202320SEIS630-03.txt
# It might be nice to have more mandatory (graded, even just for completion) hands on assignments and projects throughout the semester.
# 202320SEIS630-03.txt
# I think it'd be nice if a larger segment of class time was hands on projects and smaller segment being the lecturing.
# 202320SEIS630-03.txt
# Not poorly taught, just far too easy and slow to be engaging.
#
# 202320SEIS630-03.txt
# This was was amazing.
# 202320SEIS630-03.txt
# Learned a lot.
# 202320SEIS630-03.txt
# Thanks a lot professor!
#
# 202320SEIS630-03.txt
# I have learned many a things from your course.
# 202320SEIS630-03.txt
# Thank you for your hardwork and for explaining concepts more clearly.
# 202320SEIS630-03.txt
# I really appreciate it!
#
# 202320SEIS630-03.txt
# Thank you so much for your well prepared lectures.
# 202320SEIS630-03.txt
# I always enjoy following your hand-on activity after each lecture and I appreciate how approachable you are.
#
# 202320SEIS630-03.txt
# Professor Abe made class enjoyable since you can tell he is passionate about the subject.
# 202320SEIS630-03.txt
# He provided ways to make the learning interactive and related it to real life events.
# 202320SEIS630-03.txt
# Overall this class was very enjoyable and I learned alot more about oracle and other databases which will help in my current job!
#
# 202320SEIS630-03.txt
# Very knowledgeable and passionate about the subject taught.
# 202320SEIS630-03.txt
# Real world examples and other topics were brought to class which helped showcase class related topics.
# 202320SEIS630-03.txt
# It's evident that there is care and effort brought to every class and questions answered.
#
# 202040SEIS632-02.txt
# Good teacher, appreciated the lectures greatly and appreciated his seeking feedback on course improvement.
# 202040SEIS632-02.txt
# Hands on part of lecture was especially valuable.
#
# 202040SEIS632-02.txt
# As an MBA student, this course was pretty difficult for me to understand.
# 202040SEIS632-02.txt
# Jumping right into Enterprise Miner was hard for me to grasp because it was pretty technical
# 202040SEIS632-02.txt
# and I didn't really feel like I was getting the "why" behind using that platform.
# 202040SEIS632-02.txt
# I think using more real world applications each week with Enterprise Miner might have helped.
# 202040SEIS632-02.txt
# It got better as we went into Tableau as the handouts were a little easier to follow and it was a more intuitive platform.
# 202040SEIS632-02.txt
# I do think that final project helps tie things together and gives a better meaning to the course and why I took it.
# 202040SEIS632-02.txt
# I would also recommend reworking how the lectures are presented.
# 202040SEIS632-02.txt
# The handouts are definitely helpful, but I went through them again line by line after the lecture to help with the assignments.
# 202040SEIS632-02.txt
# So it seemed like a bit of a waste to spend half our class time going step by step through the handouts.
# 202040SEIS632-02.txt
# Maybe it would be more helpful to go over different examples than what's included in the handout.
# 202040SEIS632-02.txt
# Overall, I found myself enjoying the class more once we got to Tableau and I learned a lot through the final project and relating our classwork to a real world example.
# 202040SEIS632-02.txt
# Thanks for a great semester!
#
# 202040SEIS632-02.txt
# This course was comprised of two tools learning, one for data analytics and other for visualization.
# 202040SEIS632-02.txt
# We have covered tableau much better than Enterprise miner.
# 202040SEIS632-02.txt
# May be some more practical approach was missing in this course.
# 202040SEIS632-02.txt
# Apart from Enterprise miner, there are many other data analytics tool which are better than it.
# 202040SEIS632-02.txt
# We can include other tools as well.
#
# 202040SEIS632-02.txt
# I have a lot of "moderate progress" as I have fairly substantial work history regarding this topic.
# 202040SEIS632-02.txt
# However, the professor brings a large understanding, and passion to the subject matter.
# 202040SEIS632-02.txt
# I've given my suggestion that the course material should be "flipped", but overall the course is meaningful for the average student, and with this professor, especially regarding the second half of the course.
#
# 202040SEIS632-02.txt
# the professor relied heavy on information that was taught in another class.
# 202040SEIS632-02.txt
# As someone who was from the MSA program, I felt like I was always trying to catch up and having to piece information together on my own.
#
# 202040SEIS632-02.txt
# very kind and helping professor ever i have seen.
#
# 202040SEIS632-02.txt
# Professor goes out of his way to help students learn in his class and to make them learn at their own pace with his guidance.
#
# 202020SEIS631-01.txt
# Given the difficulty of transitioning to distance learning, I think this class went well.
# 202020SEIS631-01.txt
# I found the flipped lecture format to be surprisingly effective.
#
# 202020SEIS631-01.txt
# This was one of the best classes I ever took.
# 202020SEIS631-01.txt
# professor Abe is one of the best I ever learned from.
# 202020SEIS631-01.txt
# He is humble and eager to teach no matter how long or hard it took teach me.
# 202020SEIS631-01.txt
# I would ask him questions and he would stay almost for another hour helping me out.
# 202020SEIS631-01.txt
# I would definitely recommend students to take his classes.
#
# 201920SEIS632-01.txt
# Great professor with a LOT of potential (on top of his current talents).
# 201920SEIS632-01.txt
# He is very down to Earth and fair, and I am happy to have taken the course with him as the teacher.
# 201920SEIS632-01.txt
# I look forward to seeing how his teaching methods produce the future of data-scientists!
#
# 201920SEIS632-01.txt
# Abe is very knowledgeable however needs to work on his lecturing.
# 201920SEIS632-01.txt
# The lectures are very dry and boring, and hard to listen to.
# 201920SEIS632-01.txt
# The lectures were not very interactive, and some parts I had no idea why we were doing things, or what purpose certain tests served.
# 201920SEIS632-01.txt
# The slides did not provide much info so was very hard to study from as well.
# 201920SEIS632-01.txt
# I think with some practice and more interactiveness in the class instead of just sitting listening to lecture for 3 hours would help with the class to be more interesting.
#
# 202040SEIS631-01.txt
# Thank you Professor.
# 202040SEIS631-01.txt
# I have learnt a lot.
#
# 202040SEIS631-01.txt
# Abe is an incredibly nice person and has a good taste in music so this is hard to write.
# 202040SEIS631-01.txt
# This course is very difficult to follow, when the topics are not.
# 202040SEIS631-01.txt
# Organization is key to being able to follow an instructor and while you can tell Professor Kazemzadeh knows the topics inside and out, he struggles to relay them in a fashion that is easy to digest.
# 202040SEIS631-01.txt
# Particularly, it would help if you start from a high level overview of what we are going to cover and what it is used for, before diving in and just going from step to step, waiting until the end to discuss the bigger picture.
# 202040SEIS631-01.txt
# The layout of Canvas is also not the easiest to follow.
# 202040SEIS631-01.txt
# Abe's most redeeming quality is that he cares about his students and is willing to take additional time to explain topics they may be struggling with.
# 202040SEIS631-01.txt
# Overall I would likely give the course a C-.
# 202040SEIS631-01.txt
# Most of what I learned I gathered from the book or online resources.
# 202040SEIS631-01.txt
# Lecture was supplementary at best and sometimes was more confusing than it was helpful.
# 202040SEIS631-01.txt
# I wish nothing but the best for Professor Kazemzadeh but a true reflection on how to present a lecture in an organized fashion, and probably a public speaking course, I believe would greatly benefit him and the course.
#
# 202040SEIS631-01.txt
# N/A
#
# 202040SEIS631-01.txt
# I believe he is a fair teacher who listens to all when in class and tries to reach everyone by engaging conversation and examples.
# 202040SEIS631-01.txt
# I enjoyed the class curriculum and I have definitely loved learning statistics through R.
#
# 202040SEIS631-01.txt
# This class feels like two courses that were mashed together, but not mashed together well.
# 202040SEIS631-01.txt
# There’s two subjects that we focus on R and statistics.
# 202040SEIS631-01.txt
# I feel like we need to focus on one topic for the course to be more helpful or work with R more
#
# 202040SEIS631-01.txt
# Overall I really enjoyed this course and Abe did a really good job.
# 202040SEIS631-01.txt
# He provided plenty of opportunity to grow, learn, and benefit from the material.
# 202040SEIS631-01.txt
# He also provided plenty of opportunities to do well.
# 202040SEIS631-01.txt
# And finally, he illustrated how the course material applied to real world problems and applications.
#
# 202040SEIS631-01.txt
# Tougher material to teach.
# 202040SEIS631-01.txt
# Bouncing between R and book was a bit rough.
# 202040SEIS631-01.txt
# Not sure I feel great on either, but I could do it.
#
# 202040SEIS631-01.txt
# It was a unique semester virtually with Covid.
# 202040SEIS631-01.txt
# As a business student I thought I had a good understanding of statistics coming into class which was a strength but I am not as strong when it came to R as many of the other students who came from the school of engineering.
# 202040SEIS631-01.txt
# Classmates may have had an upper hand with related experiences in python or other course work which a business student wouldn’t have.
# 202040SEIS631-01.txt
# I sometimes fell behind during the online classes practicing r and between switching screens and it could be hard to do further functions if you missed something before.
# 202040SEIS631-01.txt
# The text book was helpful when it came statistics related material but it didn’t have much direction on R, I wish maybe there was more writing or directions or another textbook to practice/learn R more outside off following along during class time.
# 202040SEIS631-01.txt
# Abe is very reasonable and it was great learning from him this semester, thank you!
#
# 202240SEIS630-03.txt
# The class is interactive and the gentle introduction of new topics helped both experienced and new students to the subject to progress with ease.
# 202240SEIS630-03.txt
# You may wish to introduce more group assignments earlier on in the course, if it is possible.
# 202240SEIS630-03.txt
# Your patience with everyone was awesome.
# 202240SEIS630-03.txt
# Thank you.
#
# 202240SEIS630-03.txt
# loved the way of teaching, group discussions.
# 202240SEIS630-03.txt
# Overall enjoyed the course!!
#
# 202240SEIS630-03.txt
# For future semesters, it may be helpful to pare down the readings a bit, or highlight the most important sections of a reading beforehand.
# 202240SEIS630-03.txt
# In lecture, it often felt like it took too long to get us into the material.
# 202240SEIS630-03.txt
# Getting into the material quicker could give more hands-on time and activities, which would be very appreciated.
#
# 202240SEIS630-03.txt
# I thought the course was really helpful in terms of understanding concepts better and applying them in the actual sql queries because of the final project where we put all the concepts in on thing, so we could see how to use the data modeler to create the diagrams and then using either LiveSQL or the live class database to display our data to our classmates, it really helped knowing how to actual see how everything we learned applyed to real life.
#
# 202240SEIS630-03.txt
# Great course and instructor.
# 202240SEIS630-03.txt
# Hopefully I am able to take more classes with Professor Kazemzadeh.
# 202240SEIS630-03.txt
# My progress was made evident with the final project, where I surprised myself developing my own DBMS.
# 202240SEIS630-03.txt
# Professor was exceptional in knowledge and teaching.
#
# 202240SEIS630-03.txt
# Should concentrate more time on introducing the materials than reviewing the homework.
# 202240SEIS630-03.txt
# We could explore the topics more rather than learn them by ourselves.
# 202240SEIS630-03.txt
# Reading should be shorter.
# 202240SEIS630-03.txt
# Reading takes a lot of time and sometimes I end up giving it up.
#
# 202240SEIS630-03.txt
# The professor was amazing and very informative.
# 202240SEIS630-03.txt
# Really made foreign topics easy.
#
# 202240SEIS630-03.txt
# Amazing teacher and methods, difficult subject matter to wrap head around with busy schedule and zero prior experience.
#
# 202240SEIS630-03.txt
# Overall, this has been a great class for someone who had no database knowledge/experience.
# 202240SEIS630-03.txt
# The workload is manageable and the professor does an excellent job.
#
# 202240SEIS630-03.txt
# You did a very good job with teaching.
# 202240SEIS630-03.txt
# I also love that we could approach you when we had issues.
# 202240SEIS630-03.txt
# Thank you!
#
# 202240SEIS630-03.txt
# It was a great learning experience taking thi course.
#
# 202240SEIS630-03.txt
# Professor Abe is a great instructor
# 202240SEIS630-03.txt
# and I felt I learnt a lot this semester.
# 202240SEIS630-03.txt
# The course was extremely interesting and the instructor is clearly knowledgeable, approachable and focuses more on practical things.
# 202240SEIS630-03.txt
# Definitely I would put my effort in reading the course material earlier to class as per the ask but I would expect him to teach the basics too in the class.
#
# 202320SEIS601-01.txt
# The Assignments and Grading system is really good.
# 202320SEIS601-01.txt
# It's more focused towards learning aspects rather then just the grading criteria.
# 202320SEIS601-01.txt
# Good teaching methods by professor.
#
# 202320SEIS601-01.txt
# His java background seem not that much great.
# 202320SEIS601-01.txt
# I think he has good background in pythoton so its better assign mastered instructor for this course
#
# 202320SEIS601-01.txt
# Abe was well-informed in this area of study and did a great job focusing on the code itself as well as other peripheral information that enhances a student's knowledge about programming / computer science.
# 202320SEIS601-01.txt
# There were some times in class when we dove deep into something that I didn't have questions on so it felt a little bit like an unnecessary use of class time.
# 202320SEIS601-01.txt
# (3 evening hours every week is a long time away from my family and I want to always be getting high value return from that time)
# 202320SEIS601-01.txt
# But I suppose it was helpful to to hear others discuss the code/lecture and learn new perspectives in that way.
#
# 202320SEIS601-01.txt
# The class structure was pretty good.
# 202320SEIS601-01.txt
# I though it was a good choice to a final project over a final exam.
# 202320SEIS601-01.txt
# The topics were interest although towards the end, the readings were somewhat long.
#
# 202320SEIS601-01.txt
# The professor is good and responsible.
#
# 202320SEIS601-01.txt
# I really appreciate Dr. Kazemzadeh's approach to this course and the topic material.
# 202320SEIS601-01.txt
# I felt like there was a good balance between different types of evaluations (quizzes, videos, etc.).
# 202320SEIS601-01.txt
# Dr. Kazemzadeh was approachable and helpful in answering questions.
#
# 202320SEIS601-01.txt
# I did enjoy the quizzes that we had to take.
# 202320SEIS601-01.txt
# They weren't too easy or too difficult, but a good challenge to see where I am at.
#
# 201840SEIS632-01.txt
# A decent course, with interesting material, but having a professor (Kazemzadeh) teach from another professor's (Rege) materials and slides seemed ineffective.
# 201840SEIS632-01.txt
# The lack of a course text, or something more concrete to follow lead to confusion at times in knowing what was pertinent.
# 201840SEIS632-01.txt
# I don't feel like any one topic was covered in-depth, and only gained a surface-level understanding of some things.
#
# 201840SEIS632-01.txt
# Thank you for making yourself so available outside of class!
#
# 201840SEIS632-01.txt
# I think this overall course was good, I think that if the professor had his own slides for the course it would have been better for our learn purposes, using course material that the other professor had made it harder on him as a professor but also us as students.
# 201840SEIS632-01.txt
# I think over time with his understanding of the material he will get more comfortable.
#
# 201840SEIS632-01.txt
# I think that there should be a pre-requisite for this class that students need to completed OPMT-600 (Stat Methods for Dec Making) before being able to take this class.
# 201840SEIS632-01.txt
# I am also taking the stats class in addition to this class, but much of what is taught in the second part of the semester in the stats class is the foundation for all the math related to the analytics part in the first half of the semester for this class.
# 201840SEIS632-01.txt
# That was a major struggle.
#
# 201840SEIS632-01.txt
# Great effort for a first course at St. Thomas.
# 201840SEIS632-01.txt
# Thanks for trying hard!
#
# 201840SEIS632-01.txt
# This course is does not meet the level of graduate school.
# 201840SEIS632-01.txt
# I felt it was a basic introductory class that should have been a prerequisite for a class that took the time to explore the concepts in better detail.
#
# 201840SEIS632-01.txt
# He has a great knowledge and experience in his field, and has got very good personality and is always willing to help students.
# 201840SEIS632-01.txt
# He will continue to explain things until the student understand the material.
# 201840SEIS632-01.txt
# He makes him self available to students even after class hours.
# 201840SEIS632-01.txt
# I had stopped by at his office many times this semester when I had questions.
# 201840SEIS632-01.txt
# He is always accepting and willing to help students.
# 201840SEIS632-01.txt
# Abe is a great professor.
#
# 201840SEIS632-01.txt
# Lecture slides have very little dialogue to refer back to.
# 201840SEIS632-01.txt
# The only way to study material presented by Dr. Kazemzadeh was to be a fast writer taking good notes or reviewing the 3 hours lectures that were recorded.
# 201840SEIS632-01.txt
# I would prefer the lecture slides gave more dialogue and there was a course textbook as an assistive aid.
# 201840SEIS632-01.txt
# Dr. Kazemzadeh shows that he is passionate about data analytics and visualization and wants everyone he is teaching to understand the topics.
# 201840SEIS632-01.txt
# His style of presenting the information is not well suited for my learning style.
# 201840SEIS632-01.txt
# I wish we would have done more hands-on practice with visualization as I felt we spent too much time looking at visualizations - it felt redundant.
#
# 201840SEIS632-01.txt
# I think it would help to have a specific set of data that students use throughout the analytics and visualization portions of the course to get a more full understanding of the lifespan of a data analytic process with one set of data.
# 201840SEIS632-01.txt
# Also, I don't really have any insights as to how to correct this, but I put at least 20 hours into preparing for the midterm and at least 20 hours preparing for the final and came out of both feeling utterly dejected.
# 201840SEIS632-01.txt
# It was frustrating to put that much effort into studying and still feel like (a) you don't understand what is expected of you on the exam and (b) to feel like you have a good grasp on the topics going into the exam and coming out feeling like you know nothing.
# 201840SEIS632-01.txt
# I know we had study guide slides, but those simply truncated the slides from the course.
# 201840SEIS632-01.txt
# Maybe more in class (or take home) practice problems that better prepare us for what to expect on the midterm, at the very least to prepare for the formatting of the exam.
# 201840SEIS632-01.txt
# Lastly, I am in the business analytics program and have no analytic or visualization background; I am interested in the subject and broaching that field for work, which is why I enrolled in the program.
# 201840SEIS632-01.txt
# At times in this class I really felt like this was a handicap and that we were working off an assumption of knowledge that I did not have.
# 201840SEIS632-01.txt
# I don't mean the above statements to come off as complaining or whining, just merely conveying some of the speed bumps I encountered this semester.
# 201840SEIS632-01.txt
# ...
# 201920SEIS632-02.txt
# I felt that the machine learning content was a little rushed, but understand the desire to have that as part of the course curriculum.
# 201920SEIS632-02.txt
# Initially I though it would have been better to expand the time given to the machine learning part, but in retrospect, the visualization content is so useful that I wouldn't want to give it less time.
# 201920SEIS632-02.txt
# I liked the individual projects a lot, but I think if they are individual projects we should probably present them as such rather than group presentations.
# 201920SEIS632-02.txt
# One takeaway from our class presentation is we need a hard time limit and a timer to keep presentations from being too long.
#
# 201920SEIS632-02.txt
# Wish we had spent more time on using Tableau and SAS Enterprise Miner to convey more statistical analysis related data.
# 201920SEIS632-02.txt
# Also use Tableau to do table joins and other data cleansing and merging technics.
# 201920SEIS632-02.txt
# Overall learned a lot from this course and the professor was incredibly generous with his time and put a lot of effort into making the course easy to understand.
#
# 201920SEIS632-02.txt
# The course is too lengthy for the class duration.
# 201920SEIS632-02.txt
# Practical lectures on SAS ERM or Tableau not both with the theory part.
# 201920SEIS632-02.txt
# I think because of this issue the professor tried hard to make the course as smooth as possible.
# 201920SEIS632-02.txt
# They're was too much that had to be covered in a 3 hour class, 70% of the classes weren't able to finish what was planned to be covered in them.
#
# 202020SEIS632-03.txt
# Abe is a practical, passionate, and thoughtful teacher who knows how to balance between making sure that students are learning the material and getting fair grades.
# 202020SEIS632-03.txt
# My only feedback is that the class seems to be covering a lot of materials, 3 hours and 15 mins don't seem enough to cover it all, at some point by the end of each class most students check out and it became just a matter of being there, maybe a better distribution of class activity will be helpful, more peer interaction and cut back on some of the material or demand that student read three pages which covers the basics of each day's class before they come to the class.
#
# 202020SEIS632-03.txt
# Professor Abe was an absolute blessing to have as we transitioned to online learning.
# 202020SEIS632-03.txt
# He was approachable, funny, and so helpful in anything that we needed.
#
# 202020SEIS632-03.txt
# Great and understanding instructor who handled the difficulties well throughout the semester.
#
# 201940SEIS631-03.txt
# While Abe is one of the kindest professors I have had over the course of my undergraduate and MA programs previously, he struggles in the classroom.
# 201940SEIS631-03.txt
# It is apparent he does not look at the slides before class.
# 201940SEIS631-03.txt
# He cannot always solve the practice problems which the answers are provided on his instructor set of slides.
# 201940SEIS631-03.txt
# When attempting to answer student questions, they are rarely resolved and often include the phrase "google that."
# 201940SEIS631-03.txt
# He has admitted his primary coding language is python so he sometimes doesn't code right in R or will spend copious amounts of time talking about how you could code it in python when the class is about R. Abe also did not adequately prepare for the semester because he put up the syllabus and shared it with the bookstore, but on the first night of class realized he put the wrong copy of the book in the syllabus which many of us had already purchased.
# 201940SEIS631-03.txt
# Luckily, you can get an e-edition for free if you choose to, but that is slightly unethical in my opinion so I double paid for the book.
#
# 201940SEIS631-03.txt
# I think we spend too much class time on statistics and not enough on R. Make getting a book for R mandatory and assign reading.
# 201940SEIS631-03.txt
# The trick for this class maybe is how to balance statistical concepts with R. Assign both homework from the book and R assignments.
# 201940SEIS631-03.txt
# Some outside readings or examples of how the industry collect data, analyze data, and make statistical observations would be helpful to help us put the knowledge into work.
# 201940SEIS631-03.txt
# Nothing is better than real world examples.
#
# 201940SEIS631-03.txt
# Abe is a great communicator and professor.
# 201940SEIS631-03.txt
# He has very deep knowledge of the subject as well as technical skills with R. He is fair with grading as well as providing an opportunity to recover some ground with extra-points with assignments and quizzes after not doing so well with the exam.
# 201940SEIS631-03.txt
# He is open to getting feedback from his students in order to adjust and make sure students learn from his course.
# 201940SEIS631-03.txt
# The course book we are using is good
# 201940SEIS631-03.txt
# but I feel that with Abe's background and qualifications, he can take that book, customize it, and make the course even better.
# 201940SEIS631-03.txt
# I have no doubt that relying on the book's direction/path for the course would definitely suffice for what the course is trying to achieve but if it can be customized to fit the overall program would be even better.
# 201940SEIS631-03.txt
# My only comment about the course (not on Abe particularly) is the use of the R language.
# 201940SEIS631-03.txt
# I'm sure it is a great statistical software but I would have liked to use python with the course for the purpose of consistency, proficiency, and logical progression from requiring students to go through Python as a pre-requisite, taking the foundations in data analysis, machine-learning, up to the artificial intelligence course.
# 201940SEIS631-03.txt
# I understand R or python (or any other software) are just tools and regardless of the tools used, the goal of the course is to gain knowledge and understanding in the foundations of statistics.
# 201940SEIS631-03.txt
# However, I feel that proficiency in the use of the software by using it all through-out the program is just as important.
# 201940SEIS631-03.txt
# I think the big head-scratcher (at least for me) is why would the SEIS 631 course require SEIS 603 when python is not even used at all in SEIS631?
#
# 202120SEIS630-03.txt
# I like Abe's teaching style.
# 202120SEIS630-03.txt
# There is a lot of emphasis on the slides during lecture, but that helps me because I don't think I'd retain the information by only reading it in a text book.
# 202120SEIS630-03.txt
# He also does a good job pulling other students' professional experiences, which is very interesting to me and helps me see how this type of work is actually applied in current professional settings.
#
# 202120SEIS630-03.txt
# More hands on SQL work would be really fun to add to the course.
# 202120SEIS630-03.txt
# Aside from that I really liked the class and the teaching style of the professor.
#
# 202120SEIS630-03.txt
# The freedom to choose a topic for the final project was excellent - even someone with a lot of database background (as I have) is able to move on to a new and interesting topic.
#
# 202120SEIS630-03.txt
# Abe is great.
# 202120SEIS630-03.txt
# he is really flexible with homework and tests, and is always open to questions.
# 202120SEIS630-03.txt
# i really liked the project, we did it in steps instead of all at once, it made it easier to digest.
# 202120SEIS630-03.txt
# he is also really understanding that when it comes to everyone being working adults, he really wants us to learn the material regardless of whether your homework answer is right or not, so i appreciate that way of grading.
# 202120SEIS630-03.txt
# anyways, i hope to take a class with abe again.
#
# 202120SEIS630-03.txt
# The course was a learning process for all.
# 202120SEIS630-03.txt
# Every class needs to focus in providing students with projects to put on to github instead of exams.
# 202120SEIS630-03.txt
# These are not english class we are trying build skill for.
# 202120SEIS630-03.txt
# We need to be doing what we learn with regularity.
#
# 202120SEIS630-03.txt
# I really liked the class.
#
# 202120SEIS630-03.txt
# I would say that I was a beginning to low intermediate student when it came to databases.
# 202120SEIS630-03.txt
# I have a BS in computer science, but I don’t really interact with databases at a detail level in my career.
# 202120SEIS630-03.txt
# I think this course did a decent job of covering a wide array of database topics; maybe too wide.
# 202120SEIS630-03.txt
# So of the discussion on how to install various tools and applications that we did not actually wind up using seemed like a poor use of time.
# 202120SEIS630-03.txt
# There should have been much more homework, especially hands on work.
# 202120SEIS630-03.txt
# I felt like there was very little practice to learn from our mistakes.
# 202120SEIS630-03.txt
# The semester started out with a lot of hands-on work, jumping directly into doing a large volume of SQL statements.
# 202120SEIS630-03.txt
# I was enthused; it was actually FUN!
# 202120SEIS630-03.txt
# We got immediate feedback with either being rewarded with a result of our query, or an error that we then needed to research and keep trying until it worked.
# 202120SEIS630-03.txt
# Later, as we were working through some very, very long chapters in the book, there was little hands on.
# 202120SEIS630-03.txt
# I feel like there should have been assignments for every class session.
# 202120SEIS630-03.txt
# The book was not exclusively, but highly focused on Microsoft SQL Server and not Oracle.
# 202120SEIS630-03.txt
# I get it that Oracle may be highly prominent in the industry and certainly a good employment skill for students, it was a bit frustrating to have a textbook that leaned towards MS and the work was 100% Oracle.
# 202120SEIS630-03.txt
# The breakout rooms did not seem very valuable to me, mainly because we did not always have a lot to talk about.
# 202120SEIS630-03.txt
# This brings me back to more frequent homework.
# 202120SEIS630-03.txt
# If we had assignments for each class, then the breakouts would have held more value to discuss the problems and outcomes.
# 202120SEIS630-03.txt
# Also, I think if we had more static breakout groups we would have grown together and been able to converse more.
# 202120SEIS630-03.txt
# Understand the value of mixing it up, so a compromise could be what I have had in other classes: 1 static group prior to midterm
# 202120SEIS630-03.txt
# and then we get new teams for 2nd half of semester.
# 202120SEIS630-03.txt
# And to take that one step further, I think that it would have been really interesting if the final project was a team project.
# 202120SEIS630-03.txt
# This would have been more “real world” to create the problem solution as a team since that is how people would do it on the job.
# 202120SEIS630-03.txt
# Many of my other GPS classes have had team midterm and final projects.
# 202120SEIS630-03.txt
# It allows each person to use their strengths and learn from the others, especially with getting feedback.
# 202120SEIS630-03.txt
# “Hands On” segments at the end of class were really an instructor demo.
# 202120SEIS630-03.txt
# There was not the time, prepared instructions, or ability to multitask with watching what was happening in the demo and try to replicate it at the same time.
# 202120SEIS630-03.txt
# Plus they were always at the very end and we often went over the class end time.
# 202120SEIS630-03.txt
# This course, with 3 sections and lot of material, seems like it could be a good candidate for a Flipped Course format, with the lectures pre-recorded and the class sessions reserved for exercises, team work on projects, questions to the professor, etc.
# 202120SEIS630-03.txt
# It would certainly cut down on the need to repeat the lecture 3 nights a week.
# 202120SEIS630-03.txt
# Overall, I think this was a good course with challenging subject material and was a good showing for the professors first time teaching this class.
#
# 202120SEIS630-03.txt
# I really learned a lot taking this class, I wasn't as big a fan of the textbook but I have really had my eyes opened to SQL and how useful it is
# 202120SEIS630-03.txt
# and It has already helped me out and work.
# 202120SEIS630-03.txt
# Thanks Professor!
#
# 202120SEIS630-03.txt
# Professor has good skill sets for this course to explain and provides real example.
# 202120SEIS630-03.txt
# If the professor could cover another SQL software for experimentation that would be helpful ( eg.
# 202120SEIS630-03.txt
# Microsoft SQL server management studio, MySQL, PostgreSQL).
#
# 202120SEIS630-02.txt
# Great professor!
# 202120SEIS630-02.txt
# Very helpful and knowledgeable
#
# 202120SEIS630-02.txt
# Professor Abe has been excellent.
# 202120SEIS630-02.txt
# I appreciate the impact this class has had on me professionally
#
# 202120SEIS630-02.txt
# This was his first time teaching the course so we all were learning the pace of the course with him.
# 202120SEIS630-02.txt
# I enjoyed his flexibility and how he tries to engage with the students (despite how covid and zoom has been with students interacting).
# 202120SEIS630-02.txt
# I would say that overall he did a good job but I, personally, would've enjoyed more hands on work and less textbook reading and discussion of the textbooks.
# 202120SEIS630-02.txt
# I think with databases, doing rather than reading, helps comprehend what everything does.
#
# 202120SEIS630-02.txt
# Prior to taking this course I feel I had a very strong foundation for the content covered in Database Management Systems and Design, which was much different than many other individuals I found were taking the course.
# 202120SEIS630-02.txt
# I thought Abe did an excellent job of catering to the differing levels of understanding and skillsets.
# 202120SEIS630-02.txt
# The course followed a very meaningful sequence of concepts, and was delivered in a way that I felt everyone was set up for success.
# 202120SEIS630-02.txt
# Too, I appreciated the time Abe put into sending weekly class emails, previews of the course content in modules, and giving enough information ahead of time so students who have responsibilities outside of class could really plan and stay on top of course content.
# 202120SEIS630-02.txt
# Overall I was very pleased with my experience and the instruction I received.
#
# 202120SEIS630-02.txt
# Professor Kazemzadeh is an incredibly thorough teacher.
# 202120SEIS630-02.txt
# He is very in-depth the topics he teaches.
# 202120SEIS630-02.txt
# While sometimes learning from him can be like trying to take a sip of water from a firehose, I do learn quite a bit.
# 202120SEIS630-02.txt
# I believe that he does a good job of teaching to a diverse background of students.
# 202120SEIS630-02.txt
# I would like more hands on activites, but I will always take Professor Kazemzadeh if he's available for a course I need to take.
#
# 202120SEIS630-02.txt
# I think it would have helped if some of the assignments were more structured.
# 202120SEIS630-02.txt
# That way it would be easier to see if we are making any mistakes after the answer key is published.
# 202120SEIS630-02.txt
# I also think it would help if we were forced to use SQL more.
#
# 202120SEIS630-02.txt
# More hands on activities or activities with quicker/instant feedback would be useful to judge understanding.
# 202120SEIS630-02.txt
# Examples: Kahoot, more frequent/well defined assignments or mini-projects.
#
# 202120SEIS630-02.txt
# I felt that the instructor did not have quite enough depth of knowledge to teach this course very effectively.
#
# 202120SEIS630-02.txt
# Abe is very committed to helping his students; He seemed well-versed and I appreciate his attempts help the class engage with one another.
# 202120SEIS630-02.txt
# I would have liked more Oracle assignments and hands-on activities (instead of demos by Prof Abe).
# 202120SEIS630-02.txt
# I think for what I paid for tuition, this was not worth the tuition paid.
# 202120SEIS630-02.txt
# Assignments forced us to do things we barely learned in class, I ended learning more off Youtube than in class.
# 202120SEIS630-02.txt
# Final project was a little all over the place (though the flexibility in topic was very appreciated) and not as organized as I think it could have been.
